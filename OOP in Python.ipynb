# %% [markdown]
# **OOP**: 1.Object
# 2.Class
# 3.Polymorphism
# 4.Encapsulation
# 5.Inheritnce
# 6.Abstraction

# %% [markdown]
# **Class**: Dataype is a class, and when datatype ka varible banate ho that is obejct of that class.
#
# L=[1,2,3,4]
# here l is a object . kaunsi class ka ???
# list class ka.
#
# Class consist of Data/property and Function.
#
# and It is always return in a Pascal case.
# CarWagonr(Sabb stick raheteh h.)

# %%
class Atm:
  #function inside call is called method.
  #def mltb funtion lkin class k ander h toh method.


# class k ander variable decalre krete ho, woh apko krna hota h ek Special method 
#hoti h init >>uske ander krna hota h .

 def _init_(self):#init method
   #Init is also a constructor.
   #it is a special method jiske ander rakha hua code automatically
   #execute hota h jab app uski class ka object bana te ho
   #for eg: Sbi=Atm() 
   #Syntax: object name= class name
   
   self.pin=""
   self.balance=0

   self.menu()
  
  # menu method
def menu(self):
    user_input=input("""What u want to do?
    1.Enter 1 to create pin
    2.Enter 2 to deposit
    3.Enter 3 to withdraw
    4.Enter 4 to check balance
    5. Enter 5 to exit
    """)
    
    if user_input=="1":
      print("Create Pin")
    elif user_input=="2":
        print("Withdraw")
    elif user_input=="3":
          print("deposit")
    elif user_input=="4":
            print("Balance")
    else:
      print("Bye.")

# %% [markdown]
# Constructor: Magic method : it is not called by the object.

# %%
#What is (self)???

print(id(self))
#if we run we will get id of self and id of object i.e. sbi will
#be same.

#sbi=atm()
#so self is sbi, self lagana padta h method m.

# %%
#What is instance variable???
#type of variable for which type of variable is diffrent for different variable
#for eg self.pin
#self.balance 
#so both should be different.

# %%
#what is refrence variable???
#object jo jis varible m store krte ho usko kehte h refrence variable
#for eg: sbi=Atm()
#here sbi is refrence variable

# %%
#Static Method: Special method with which we can access without object. and used 
#when we are dealing with static variable.


#counter which is written above class.
