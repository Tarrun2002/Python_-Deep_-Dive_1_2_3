# %% [markdown]
# SETS : Set is a Mutubale datatype.
#        Set does not allow duplictae.
#        Set does not have Slicing.

# %%
#Create
S1=set()
S1
type(S1)
# Out:
# set

# %%
S1={1,2,3,4,5}
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S2={"Hello",1,24,True}
S2
# Out:
# {1, 24, 'Hello'}

# %%
#Here List is mutable 
#Set does not allow Mutable.
S3={[1,2,3],"Hello"}
S3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-ff23956ab5a3> in <cell line: 3>()
#       1 #Here List is mutable
#       2 #Set does not allow Mutable.
# ----> 3 S3={[1,2,3],"Hello"}
#       4 S3
#       5 #Here i use tuple
#
# TypeError: unhashable type: 'list'

# %%
#Here i use tuple 
S3={(1,2,3),"Hello"}
S3
# Out:
# {(1, 2, 3), 'Hello'}

# %%
#Set do not allow duplicate
S4={1,2,3,3,4,4}
S4
# Out:
# {1, 2, 3, 4}

# %%
S5={(1,2,3),"Hello"}
S5
# Out:
# {(1, 2, 3), 'Hello'}

# %%
S6={{1},{2}}
#Set ke ander set nhi chalta h 
#Coz it does not allow muttubale data type.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-1e1985383d1b> in <cell line: 1>()
# ----> 1 S6={{1},{2}}
#
# TypeError: unhashable type: 'set'

# %%
S1
id(S1)
# Out:
# 140503748135616

# %%
S1[2]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-4fa4bdc91cd3> in <cell line: 1>()
# ----> 1 S1[2]=100
#
# TypeError: 'set' object does not support item assignment

# %%
#Here we have converted a Set onto a list and then made addition and deletion.
S1
L=list(S1)
L
L[0]=100
L
S1=set(L)
id(S1)
# Out:
# 140503059864256

# %% [markdown]
# Above Here we can observe that There is a change in a Addresses. SO we cannot edit or delete.

# %%
#ADDition: We can do edition
#Check id if you want.
S1
S1.add(6)
S1
id(S1)
# Out:
# 140503059864256

# %%
S1.add(8)
id(S1)
# Out:
# 140503059864256

# %%
#Deletion
S2
del S2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-73e13beb711f> in <cell line: 2>()
#       1 #Deletion
# ----> 2 S2
#       3 del S2
#
# NameError: name 'S2' is not defined

# %%
del S1[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-c7b002eddb68> in <cell line: 1>()
# ----> 1 del S1[0]
#
# NameError: name 'S1' is not defined

# %%
S1={2,3,100,5,4,6,7}
S1
S1.remove(100)
S1
S1.pop()
#Becoz of Hashing is has removed all element.
# Out:
# 2

# %%
S1+S3
#it does not allow Concatination
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-1359296d9cce> in <cell line: 1>()
# ----> 1 S1+S3
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
len(S1)
min(S1)
max(S1)
sorted(S1,reverse=True)
# Out:
# [7, 6, 5, 4, 3]

# %%
sorted(S1)
# Out:
# [3, 4, 5, 6, 7]

# %%
S1
# Out:
# {3, 4, 5, 6, 7}

# %%
S3
# Out:
# {(1, 2, 3), 'Hello'}

# %%
S1.union(S3)
# Out:
# {(1, 2, 3), 3, 4, 5, 6, 7, 'Hello'}

# %%
S1.intersection(S3)
# Out:
# set()
