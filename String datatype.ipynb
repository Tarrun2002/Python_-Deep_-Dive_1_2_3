# %% [markdown]
# Strings: Found in Java , C++.
# for appplication developer.
# not available in C.

# %%
#Strings are sequence of CHaracter.
#In python strings are a sequence of Unicode Character.

# %%
#Creating a Strings
c="Hello"
print(c)
# Out:
# Hello

# %%
#Acessing Substring from a String.
c="hello"
print(c)
# Out:
# hello

# %%
print(c[0])
# Out:
# h

# %%
print(c[::-1])
# Out:
# olleh

# %%
print(c[-4])
# Out:
# e

# %%
#Slicing

c="Hello World"
print(c)
# Out:
# Hello World

# %%
print(c[0:4])
# Out:
# Hell

# %%
print(c[2:])
# Out:
# llo World

# %%
print(c[:4])
# Out:
# Hell

# %%
print(c[:])
# Out:
# Hello World

# %%
print(c[2:6:2])
# Out:
# lo

# %%
print(c[0:8:3])
# Out:
# HlW

# %%
#with postive dont do negative
print(c[0:6:-1])

# %%
#Editind and Deleting in Strings:
c="Hello"
print(c)
# Out:
# Hello

# %%
c[0]="X"
#Strings are Immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-0d5b6ed3f4be> in <module>
# ----> 1 c[0]="X"
#
# TypeError: 'str' object does not support item assignment

# %%
#Deletion 
c
# Out:
# 'Hello'

# %%
del(c)

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-2b66fd261ee5> in <module>
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
c="hello"
print(c)
# Out:
# hello

# %%
del c[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-b6bb46c364a5> in <module>
# ----> 1 del c[0]
#
# TypeError: 'str' object doesn't support item deletion

# %%
#format
"hello my name is {} and I am {}".format("Nitish",30)
# Out:
# 'hello my name is Nitish and I am 30'

# %%
"Hello my name is {1} and i am {0}".format("Nitish",30)
# Out:
# 'Hello my name is 30 and i am Nitish'

# %%
"Hello my name is {name} and i am {age}".format(name="Nitish",age=30)
# Out:
# 'Hello my name is Nitish and i am 30'

# %%
"Who is pm of india".split()
# Out:
# ['Who', 'is', 'pm', 'of', 'india']

# %%
" ".join([ "Who is pm of india"])
# Out:
# 'Who is pm of india'
