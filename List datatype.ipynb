# %% [markdown]
# List: A datatype where we can store multiple items
#
# List vs Arrays:
# Array is Homogeneous i mean there is all type of datatype.
#
# List is Heterogeneous , we can have different datatype stored.
#
# Arrays are much faster. Ek ke baad ek items access hote s\h.
#
# List are more Programmer friendly.

# %% [markdown]
# Creating a List:

# %%
l=[]

# %%
l=[1,2,3,4,5]

# %%
l1=["hello",4,5,6,True,5+6j]

# %%
#Two dimensional List
l2=[1,2,3,[4,5]]

# %%
#Three Dimnesional List
l3=[[[1,2],[3,4]],[[5,6],[7,8]]]

# %%
l5=list("Haldia")

# %%
l5
# Out:
# ['H', 'a', 'l', 'd', 'i', 'a']

# %%
l=[1,2,3,4,5]
l[0]
# Out:
# 1

# %%
l[1]
# Out:
# 2

# %%
l[-1]
# Out:
# 5

# %%
l[1:3]
# Out:
# [2, 3]

# %%
l2=[1,2,3,[4,5]]

# %%
l2[-1]
# Out:
# [4, 5]

# %%
x=l2[-1]

# %%
x
# Out:
# [4, 5]

# %%
x[0]
# Out:
# 4

# %%
l2=[-1][0]

# %%
l2
# Out:
# -1

# %%
l3
# Out:
# [[[1, 2], [3, 4]], [[5, 6], [7, 8]]]

# %%
l3[1][1][0]
# Out:
# 7

# %%
l=[1,2,3,4]
l[0]=100
l
# Out:
# [100, 2, 3, 4]

# %%
l[1:4]=[200,300,400]
l
# Out:
# [100, 200, 300, 400]

# %%
l
l.append(1000)
l.append("hello")
l
# Out:
# [100, 200, 300, 400, 1000, 1000, 'hello']

# %%
#To add mutiple itmes do extend.
l.extend([788,899])
l
# Out:
# [100, 200, 300, 400, 1000, 1000, 'hello', 788, 899, 788, 899]

# %%
l.append([5,6])
list[l]
# Out:
# list[[100, 200, 300, 400, 1000, 1000, 'hello', 788, 899, 788, 899, 'g', 'o', 'a', 'g', 'o', 'a', 'g', 'o', 'a', 'goa', [5, 6], [5, 6], [5, 6], [5, 6]]]

# %%
l5=[1,2,3,4,5]
l5.append(20)
l5.insert(1,"swaraj")
print(l5)
# Out:
# [1, 'swaraj', 2, 3, 4, 5, 20]

# %%
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Inserting into list.

# %%
print(l5)
# Out:
# [1, 'world', 'world', 2, 3, 4, 5]

# %%
l=[1,2,3,4]
l.append(5)
l.pop()
l.insert(1,10)
print(l)
# Out:
# [1, 10, 2, 3, 4]

# %%
l
del l[0]
l
l.append("goa")
l
l.remove("goa")
# Out:
# ['goa', 'goa']

# %%
L=[1,2,3,4]
L1=[5,6,7,8]
L+L1
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
L3=[1,2,3,[4,5]]
for i in L3: 
  print(i)
# Out:
# 1
# 2
# 3
# [4, 5]

# %%
4 in L3
# Out:
# False

# %%
sorted(L,reverse=True)
# Out:
# [4, 3, 2, 1]

# %%
L
L.sort()
L.sort(reverse=True)
L
# Out:
# [4, 3, 2, 1]

# %%
sample="HI how are you"
print(sample.split())
L=[]
for i in sample.split():
  print(i.capitalize())
  L.append(i.capitalize())
print(L)

print(" ".join(L))
# Out:
# ['HI', 'how', 'are', 'you']
# Hi
# How
# Are
# You
# ['Hi', 'How', 'Are', 'You']
# Hi How Are You

# %%
L1=[1,1,2,2,3,3,4,4]
L2=[1,2,3,1]
L=[]
for i in L1:
  if i not in L:
    L.append(i)
print(L)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Tuples: Similar to List
# We use here Small bracket

# %%
T1=(1,2,3,4,5)
T1
# Out:
# (1, 2, 3, 4, 5)

# %%
T2=(1,2,(3,4))
T2
# Out:
# (1, 2, (3, 4))

# %%
T3=tuple("Gao")
T3
# Out:
# ('G', 'a', 'o')

# %%
T4=(1,2,3,(4,5))
T4[-1][0]
# Out:
# 4

# %%
#Tuple are IMMUTABLE and STRING
T2=(1,2,(3,4))
T2[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-8cad31f684ac> in <cell line: 3>()
#       1 #Tuple are IMMUTABLE and STRING
#       2 T2=(1,2,(3,4))
# ----> 3 T2[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
#No deletion and Additon allowed

# %%
T3=(1,2,3)
T3
T3[0]=100
#This means tuple is Immutable.
#We cannot do addition or deletion in Tuple.
#It does not support Mutation.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-f3897305a09c> in <cell line: 3>()
#       1 T3=(1,2,3)
#       2 T3
# ----> 3 T3[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
c="I am Tarrun Jaiswal"

print(c)
# Out:
# I am Tarrun Jaiswal
